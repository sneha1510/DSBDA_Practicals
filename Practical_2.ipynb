# %% [markdown]
# <a href="https://colab.research.google.com/github/sneha1510/DSBDA_Practicals/blob/main/Practical_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Titanic.csv')

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# **Step 1:** Scan all variables for missing values and inconsistencies. If there are missing values and/or
# inconsistencies, use any of the suitable techniques to deal with them.

# %%
df.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
#dealing with null values
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# Dealing with **NULL** values.By filling mean in it

# %%
age_mean=df['age'].mean()
df['age']=df['age'].fillna(age_mean)

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex        age  sibsp  parch  ticket      fare    cabin embarked  \
# ...

# %%
df.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age             0
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %% [markdown]
# **Changing Data type of age which is float previously**

# %%
df['age']=df['age'].astype(int)

# %%
df.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age            int64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex  age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# replace missing values with
# mode

# %%
df.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age             0
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %% [markdown]
# replace missing values with
# median

# %%
fare_median=df['fare'].median()
df['fare']=df['fare'].fillna(fare_median)

# %%
df.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age             0
# sibsp           0
# parch           0
# ticket          0
# fare            0
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %% [markdown]
# replace missing values with
# **mode**

# %%
boat_mode = df['boat'].mode()[0]
df['boat']=df['boat'].fillna(boat_mode)

# %%
df.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age             0
# sibsp           0
# parch           0
# ticket          0
# fare            0
# cabin        1014
# embarked        2
# boat            0
# body         1188
# home.dest     564
# dtype: int64

# %%
#deleting by row with index
df = df.drop(1)

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                              Anderson, Mr. Harry
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex  age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
#drop column
df=df.drop('body',axis=1)

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                              Anderson, Mr. Harry
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex  age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# Data transformation for : to change the scale for better
# understanding of the variable named as fare

# %%
df.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age            int64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# home.dest     object
# dtype: object

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
df['scaled_fare'] = scaler.fit_transform(df[['fare']])

# %%
print(df[['fare', 'scaled_fare']])
# Out:
#           fare  scaled_fare
# 0     211.3375     3.449919
# 2     151.5500     2.292099
# 3     151.5500     2.292099
# 4     151.5500     2.292099
# 5      26.5500    -0.128600
# ...        ...          ...
# 1304   14.4542    -0.362843
# 1305   14.4542    -0.362843
# 1306    7.2250    -0.502840
# 1307    7.2250    -0.502840
# 1308    7.8750    -0.490253
#
# [1308 rows x 2 columns]

# %% [markdown]
# Scan all numeric variables for outliers. If there are outliers, use any of the suitable
# techniques to deal with them.
# **If there are outliers, use the following techniques to
# deal with them. a)min max normalization b)z-score normalization c)Box plot**

# %% [markdown]
# 1.Box Plot

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
newdf=df[df['fare']>150]

# %%
newdf.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# **2.Min Max normalization**

# %% [markdown]
# Data difference between parch and fare is very huge in terms of max

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1308.000000  1308.000000  1308.000000  1308.000000  1308.000000
# mean      2.295872     0.381498     0.371349     0.498471     0.383792
# std       0.837390     0.485940     0.160982     1.041965     0.864737
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.000000     0.275000     0.000000     0.000000
# 50%       3.000000     0.000000     0.362500     0.000000     0.000000
# 75%       3.000000     1.000000     0.437500     1.000000     0.000000
# max       3.000000     1.000000     1.000000     8.000000     9.000000
#
#               fare  scaled_fare            29         2        30  ...  \
# count  1308.000000  1308.000000  1.308000e+03  1308.000  1308.000  ...
# mean     33.190666     0.000000  3.625000e-01     0.025     0.375  ...
# std      51.657729     1.000382  5.553238e-17     0.000     0.000  ...
# ...

# %%
import seaborn as sns

# %% [markdown]
# Here is huge range. By normalizing we will keeping data in range of 0 to 1

# %%
sns.displot(df['fare'])

# %% [markdown]
# **Min max Scaling**
#
# (value-min)/(max-min)

# %%
df_temp=df.copy()

# %%
df_temp['fare']=(df_temp['fare']-df_temp['fare'].min())/(df_temp['fare'].max()-df_temp['fare'].min())

# %%
sns.displot(df_temp['fare'])
