# %% [markdown]
# <a href="https://colab.research.google.com/github/sneha1510/DSBDA_Practicals/blob/main/Practical_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('data.csv')

# %%
df
# Out:
#    Age  Income
# 0   15      20
# 1   15      30
# 2   15      40
# 3   15      50
# 4   27      60
# 5   27      70
# 6   60      70

# %%
age_gropups=pd.cut(df['Age'],bins=[0,15,59,99],labels=['child','working age','senior citizen'])

# %%
print("\nMean")
print(df.groupby(age_groups)['Income'].mean())
# Out:
# Mean
# Age
# Children          35.0
# Working Age       65.0
# Senior Citizen    70.0
# Name: Income, dtype: float64

# %%
print("Median")
print(df.groupby(age_groups)["Income"].median())
# Out:
# Median
# Age
# Children          35.0
# Working Age       65.0
# Senior Citizen    70.0
# Name: Income, dtype: float64

# %%
print("Min")
print(df.groupby(age_groups)["Income"].min())
# Out:
# Mode
# Age
# Children          20
# Working Age       60
# Senior Citizen    70
# Name: Income, dtype: int64

# %%
print("Max")
print(df.groupby(age_groups)["Income"].max())
# Out:
# Max
# Age
# Children          50
# Working Age       70
# Senior Citizen    70
# Name: Income, dtype: int64

# %%
print("Standard deviation")
print(df.groupby(age_groups)["Income"].std())
# Out:
# Standard deviation
# Age
# Children          12.909944
# Working Age        7.071068
# Senior Citizen          NaN
# Name: Income, dtype: float64

# %%
df2=pd.read_csv("iris.csv")

# %%
df2
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df2.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df2.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %% [markdown]
# Way 1
#  Write a Python program to display some basic statistical details like percentile, mean, standard
# deviation etc. of the species of ‘Iris-setosa’, ‘Iris-versicolor’ and ‘Iris- verginica’ of iris.csv
# dataset. Grouped by one of the qualitative (categorical) variable from the dataset

# %%
df2.groupby("Species").describe()
# Out:
#                    Id                                                        \
#                 count   mean       std    min     25%    50%     75%    max
# Species
# Iris-setosa      50.0   25.5  14.57738    1.0   13.25   25.5   37.75   50.0
# Iris-versicolor  50.0   75.5  14.57738   51.0   63.25   75.5   87.75  100.0
# Iris-virginica   50.0  125.5  14.57738  101.0  113.25  125.5  137.75  150.0
#
#                 SepalLengthCm         ... PetalLengthCm      PetalWidthCm  \
#                         count   mean  ...           75%  max        count
# Species                               ...
# Iris-setosa              50.0  5.006  ...         1.575  1.9         50.0
# Iris-versicolor          50.0  5.936  ...         4.600  5.1         50.0
# Iris-virginica           50.0  6.588  ...         5.875  6.9         50.0
#
#
#                   mean       std  min  25%  50%  75%  max
# Species
# Iris-setosa      0.244  0.107210  0.1  0.2  0.2  0.3  0.6
# ...

# %%
df2.groupby("Species").describe().sum()
# Out:
# Id             count    150.000000
#                mean     226.500000
#                std       43.732139
#                min      153.000000
#                25%      189.750000
#                50%      226.500000
#                75%      263.250000
#                max      300.000000
# SepalLengthCm  count    150.000000
#                mean      17.530000
#                std        1.504540
#                min       14.100000
#                25%       16.625000
#                50%       17.400000
#                75%       18.400000
#                max       20.700000
# SepalWidthCm   count    150.000000
#                mean       9.162000
#                std        1.017319
#                min        6.500000
#                25%        8.450000
#                50%        9.200000
#                75%        9.850000
#                max       11.600000
# PetalLengthCm  count    150.000000
#                mean      11.276000
#                std        1.195317
# ...

# %% [markdown]
# **Way 2: IMP perform This one..!!! Instead of way 1**

# %%
print('Iris-setosa')
setosa = df2['Species'] == 'Iris-setosa'
print(df2[setosa].describe())
# Out:
# Iris-setosa
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  50.00000       50.00000     50.000000      50.000000      50.00000
# mean   25.50000        5.00600      3.418000       1.464000       0.24400
# std    14.57738        0.35249      0.381024       0.173511       0.10721
# min     1.00000        4.30000      2.300000       1.000000       0.10000
# 25%    13.25000        4.80000      3.125000       1.400000       0.20000
# 50%    25.50000        5.00000      3.400000       1.500000       0.20000
# 75%    37.75000        5.20000      3.675000       1.575000       0.30000
# max    50.00000        5.80000      4.400000       1.900000       0.60000

# %%
print('Iris-versicolor')
versicolor=df2['Species']=='Iris-versicolor'
print(df2[versicolor].describe())
# Out:
# Iris-versicolor
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000      50.000000     50.000000      50.000000     50.000000
# mean    75.50000       5.936000      2.770000       4.260000      1.326000
# std     14.57738       0.516171      0.313798       0.469911      0.197753
# min     51.00000       4.900000      2.000000       3.000000      1.000000
# 25%     63.25000       5.600000      2.525000       4.000000      1.200000
# 50%     75.50000       5.900000      2.800000       4.350000      1.300000
# 75%     87.75000       6.300000      3.000000       4.600000      1.500000
# max    100.00000       7.000000      3.400000       5.100000      1.800000

# %%
print("Iris-virginica")
virginica=df2['Species']=='Iris-virginica'
print(df2[virginica].describe())
# Out:
# Iris-virginica
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000       50.00000     50.000000      50.000000      50.00000
# mean   125.50000        6.58800      2.974000       5.552000       2.02600
# std     14.57738        0.63588      0.322497       0.551895       0.27465
# min    101.00000        4.90000      2.200000       4.500000       1.40000
# 25%    113.25000        6.22500      2.800000       5.100000       1.80000
# 50%    125.50000        6.50000      3.000000       5.550000       2.00000
# 75%    137.75000        6.90000      3.175000       5.875000       2.30000
# max    150.00000        7.90000      3.800000       6.900000       2.50000
